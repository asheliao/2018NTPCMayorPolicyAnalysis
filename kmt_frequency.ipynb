# %%
import pandas as pd
kmt_frequency = pd.read_csv("kmt_frequency.csv")
kmt_frequency[.index = kmt_frequency[
# Out:
#             Frequency
# Unnamed: 0
# 捷運                  9
# 安全                  8
# 打造                  6
# 推動                  6
# 托育                  5
# 空間                  5
# 增加                  5
# 鼓勵                  5
# 社區                  5
# 環境                  4
# 健康                  4
# 有機                  4
# 農業                  4
# 加強                  4
# 長                   4
# 大眾                  3
# 生活                  3
# 站                   3
# 多元                  3
# 發展                  3
# 周邊                  3
# 公益                  3
# 優先                  3
# 更                   3
# 輕軌                  3
# 產業                  3
# 吃                   3
# 擴大                  3
# 合作                  3
# 平台                  3
# ...               ...
# 幼兒園                 2
# 提供                  2
# 全市                  2
# 目標                  2
# 運動                  2
# 市府                  2
# 通用                  2
# ;                   2
# 串聯                  2
# ...
